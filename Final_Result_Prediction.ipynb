# %% [raw]
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# %matplotlib inline
# import collections

# %%
data_mat=pd.read_csv("student-mat.csv")

# %%
data_por=pd.read_csv("student-por.csv")

# %%
data_mat.shape
# Out:
# (395, 33)

# %%
data_por.shape
# Out:
# (649, 33)

# %%
data_mat.head()s
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
    finalgrade = []
    for row in data_mat['G3']:
        if row >= 10 :    finalgrade.append('pass')
        
        
        else:           finalgrade.append('fail')

# %%
data_mat['finalResult'] = finalgrade

# %%
    finalgrade = []
    for row in data_por['G3']:
        if row >= 10 :    finalgrade.append('pass')
        
        
        else:           finalgrade.append('fail')

# %%
data_por['finalResult'] = finalgrade

# %%
    ag = []
    for row in data_mat['G3']:
        if row >= 16 and row <=20 :    ag.append('A')
        elif row>=14 and row<=15 : ag.append('B')
        elif row>=12 and row <=13 : ag.append('C')
        elif row>=10 and row <=11: ag.append('D')
        
        
        else:           ag.append('E')
            
    
    data_mat['academic Grade']=ag

# %%
    ag = []
    for row in data_por['G3']:
        if row >= 16 and row <=20 :    ag.append('A')
        elif row>=14 and row<=15 : ag.append('B')
        elif row>=12 and row <=13 : ag.append('C')
        elif row>=10 and row <=11: ag.append('D')
        
        
        else:           ag.append('E')
            
    
    data_por['academic Grade']=ag

# %%
data_mat['finalResult'].value_counts()
# Out:
# pass    265
# fail    130
# Name: finalResult, dtype: int64

# %%
data_mat.dtypes
# Out:
# school            object
# sex               object
# age                int64
# address           object
# famsize           object
# Pstatus           object
# Medu               int64
# Fedu               int64
# Mjob              object
# Fjob              object
# reason            object
# guardian          object
# traveltime         int64
# studytime          int64
# failures           int64
# schoolsup         object
# famsup            object
# paid              object
# activities        object
# nursery           object
# higher            object
# internet          object
# romantic          object
# famrel             int64
# freetime           int64
# goout              int64
# Dalc               int64
# Walc               int64
# health             int64
# absences           int64
# G1                 int64
# G2                 int64
# G3                 int64
# finalResult       object
# academic Grade    object
# dtype: object

# %%
data_mat['finalResult'].value_counts()
# Out:
# pass    265
# fail    130
# Name: finalResult, dtype: int64

# %%
#Integer Encoding
School = {'GP': 1,'MS': 0} 
data_mat.school = [School[item] for item in data_mat.school]

Sex = {'M': 1,'F': 0} 
data_mat.sex = [Sex[item] for item in data_mat.sex]

Address = {'U': 1,'R': 0} 
data_mat.address = [Address[item] for item in data_mat.address]

Fam = {'GT3': 1,'LE3': 0} 
data_mat.famsize = [Fam[item] for item in data_mat.famsize]

P = {'T': 1,'A': 0} 
data_mat.Pstatus = [P[item] for item in data_mat.Pstatus]

M = {'other': 1,'services': 0,'at_home':2,'teacher':3,'health':4} 
data_mat.Mjob = [M[item] for item in data_mat.Mjob]


F = {'other': 1,'services': 0,'at_home':2,'teacher':3,'health':4} 
data_mat.Fjob = [F[item] for item in data_mat.Fjob]

R = {'course': 0,'home': 1,'reputation':2,'other':3} 
data_mat.reason = [R[item] for item in data_mat.reason]

G = {'father': 0,'mother': 1,'other':2} 
data_mat.guardian = [G[item] for item in data_mat.guardian]

SSup = {'yes': 1,'no': 0} 
data_mat.schoolsup = [SSup[item] for item in data_mat.schoolsup]

FSup = {'yes': 1,'no': 0} 
data_mat.famsup = [FSup[item] for item in data_mat.famsup]

Paid = {'yes': 1,'no': 0} 
data_mat.paid = [Paid[item] for item in data_mat.paid]

Act = {'yes': 1,'no': 0} 
data_mat.activities = [Act[item] for item in data_mat.activities]

Nur = {'yes': 1,'no': 0} 
data_mat.nursery = [Nur[item] for item in data_mat.nursery]

High = {'yes': 1,'no': 0} 
data_mat.higher = [High[item] for item in data_mat.higher]

Internet = {'yes': 1,'no': 0} 
data_mat.internet = [Internet[item] for item in data_mat.internet]

Rom = {'yes': 1,'no': 0} 
data_mat.romantic = [Rom[item] for item in data_mat.romantic]

Fres = {'pass': 1,'fail': 0} 
data_mat.finalResult = [Fres[item] for item in data_mat.finalResult]

# %%
data_mat.head()
# Out:
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0       1    0   18        1        1        0     4     4     2     3  ...
# 1       1    0   17        1        1        1     1     1     2     1  ...
# 2       1    0   15        1        0        1     1     1     2     1  ...
# 3       1    0   15        1        1        1     4     2     4     0  ...
# 4       1    0   16        1        1        1     3     3     1     1  ...
#
#    goout  Dalc  Walc  health  absences  G1  G2  G3  finalResult  \
# 0      4     1     1       3         6   5   6   6            0
# 1      3     1     1       3         4   5   5   6            0
# 2      2     2     3       3        10   7   8  10            1
# 3      2     1     1       5         2  15  14  15            1
# 4      2     1     2       5         4   6  10  10            1
#
#    academic Grade
# 0               E
# 1               E
# 2               D
# 3               B
# 4               D
#
# ...

# %%
#Integer Encoding
School = {'GP': 1,'MS': 0} 
data_por.school = [School[item] for item in data_por.school]

Sex = {'M': 1,'F': 0} 
data_por.sex = [Sex[item] for item in data_por.sex]

Address = {'U': 1,'R': 0} 
data_por.address = [Address[item] for item in data_por.address]

Fam = {'GT3': 1,'LE3': 0} 
data_por.famsize = [Fam[item] for item in data_por.famsize]

P = {'T': 1,'A': 0} 
data_por.Pstatus = [P[item] for item in data_por.Pstatus]

M = {'other': 1,'services': 0,'at_home':2,'teacher':3,'health':4} 
data_por.Mjob = [M[item] for item in data_por.Mjob]


F = {'other': 1,'services': 0,'at_home':2,'teacher':3,'health':4} 
data_por.Fjob = [F[item] for item in data_por.Fjob]

R = {'course': 0,'home': 1,'reputation':2,'other':3} 
data_por.reason = [R[item] for item in data_por.reason]

G = {'father': 0,'mother': 1,'other':2} 
data_por.guardian = [G[item] for item in data_por.guardian]

SSup = {'yes': 1,'no': 0} 
data_por.schoolsup = [SSup[item] for item in data_por.schoolsup]

FSup = {'yes': 1,'no': 0} 
data_por.famsup = [FSup[item] for item in data_por.famsup]

Paid = {'yes': 1,'no': 0} 
data_por.paid = [Paid[item] for item in data_por.paid]

Act = {'yes': 1,'no': 0} 
data_por.activities = [Act[item] for item in data_por.activities]

Nur = {'yes': 1,'no': 0} 
data_por.nursery = [Nur[item] for item in data_por.nursery]

High = {'yes': 1,'no': 0} 
data_por.higher = [High[item] for item in data_por.higher]

Internet = {'yes': 1,'no': 0} 
data_por.internet = [Internet[item] for item in data_por.internet]

Rom = {'yes': 1,'no': 0} 
data_por.romantic = [Rom[item] for item in data_por.romantic]

Fres = {'pass': 1,'fail': 0} 
data_por.finalResult = [Fres[item] for item in data_por.finalResult]

# %%
data_por.head()
# Out:
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0       1    0   18        1        1        0     4     4     2     3  ...
# 1       1    0   17        1        1        1     1     1     2     1  ...
# 2       1    0   15        1        0        1     1     1     2     1  ...
# 3       1    0   15        1        1        1     4     2     4     0  ...
# 4       1    0   16        1        1        1     3     3     1     1  ...
#
#    goout  Dalc  Walc  health  absences  G1  G2  G3  finalResult  \
# 0      4     1     1       3         4   0  11  11            1
# 1      3     1     1       3         2   9  11  11            1
# 2      2     2     3       3         6  12  13  12            1
# 3      2     1     1       5         0  14  14  14            1
# 4      2     1     2       5         0  11  13  13            1
#
#    academic Grade
# 0               D
# 1               D
# 2               C
# 3               B
# 4               C
#
# ...

# %%
#we've already checked missing values while encoding

# %%
#for finalResult analysis we will drop academic grade

# %%
data_maths=data_mat.drop('academic Grade',1)
data_port=data_por.drop('academic Grade',1)

# %%
data_maths.dtypes
# Out:
# school         int64
# sex            int64
# age            int64
# address        int64
# famsize        int64
# Pstatus        int64
# Medu           int64
# Fedu           int64
# Mjob           int64
# Fjob           int64
# reason         int64
# guardian       int64
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup      int64
# famsup         int64
# paid           int64
# activities     int64
# nursery        int64
# higher         int64
# internet       int64
# romantic       int64
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# finalResult    int64
# dtype: object

# %%
data_port.dtypes
# Out:
# school         int64
# sex            int64
# age            int64
# address        int64
# famsize        int64
# Pstatus        int64
# Medu           int64
# Fedu           int64
# Mjob           int64
# Fjob           int64
# reason         int64
# guardian       int64
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup      int64
# famsup         int64
# paid           int64
# activities     int64
# nursery        int64
# higher         int64
# internet       int64
# romantic       int64
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# finalResult    int64
# dtype: object

# %%
#all variables are numeric, we can move forward with our analysis

# %%
import seaborn as sns

# %%
#Using Pearson Correlation
plt.figure(figsize=(30,30))
cor = data_maths.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
#taking a look at correlations once more
corr = data_maths.corr()
corr = corr[['finalResult']]
corr
# Out:
#              finalResult
# school          0.031254
# sex             0.070618
# age            -0.179645
# address         0.052282
# famsize        -0.041842
# Pstatus        -0.044050
# Medu            0.115396
# Fedu            0.108057
# Mjob            0.022584
# Fjob            0.036644
# reason          0.105713
# guardian       -0.101407
# traveltime     -0.044446
# studytime       0.074613
# failures       -0.337731
# schoolsup      -0.099860
# famsup         -0.059219
# paid            0.092665
# activities      0.012414
# nursery        -0.008784
# higher          0.157708
# internet        0.061791
# romantic       -0.097737
# famrel          0.046683
# freetime       -0.018321
# goout          -0.183399
# Dalc           -0.057343
# Walc           -0.029957
# health         -0.065668
# absences       -0.092244
# G1              0.664979
# G2              0.725407
# G3              0.770042
# finalResult     1.000000

# %%
#G1,G2,G3 are higly correlated with finalResult

# %%
#We'll check outliers in corre;ated features

data_maths['G1'].plot.box()
# Out:
# <AxesSubplot:>

# %%
data_maths['G2'].plot.box()
# Out:
# <AxesSubplot:>

# %%
data_maths['G3'].plot.box()
# Out:
# <AxesSubplot:>

# %%
#0 value in G2 present but it's valid ,and we will not consider it as outlier

# %%
#TSNE

# %%
from sklearn.manifold import TSNE

X = data_maths.drop('finalResult', axis=1)
y = data_maths['finalResult']

# %%
#t-SNE
X_reduced_tsne = TSNE(n_components=2, random_state=42).fit_transform(X.values)

# %%
# t-SNE scatter plot
import matplotlib.patches as mpatches

f, ax = plt.subplots(figsize=(24,16))


blue_patch = mpatches.Patch(color='#0A0AFF', label='fail')
red_patch = mpatches.Patch(color='#AF0000', label='pass')

ax.scatter(X_reduced_tsne[:,0], X_reduced_tsne[:,1], c=(y == 0), cmap='coolwarm', label='fail', linewidths=2)
ax.scatter(X_reduced_tsne[:,0], X_reduced_tsne[:,1], c=(y == 1), cmap='coolwarm', label='pass', linewidths=2)
ax.set_title('t-SNE', fontsize=14)

ax.grid(True)

ax.legend(handles=[blue_patch, red_patch])

# %%
#i'd say they are well seperated

# %%
#NOW WE WILL DIVIDE DATASET INTO TEST AND TRAINING SET

# %%
train=data_maths[0:149]
test=data_maths[150:]

x_train=train.drop('finalResult',1)
y_train=train['finalResult']

x_test=test.drop('finalResult',1)
true_p=test['finalResult']

# %%
#Logistic Regression Model
from sklearn.linear_model import LogisticRegression
lreg=LogisticRegression()

# %%
lreg.fit(x_train,y_train)
# Out:
# C:\Users\namee\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
pred=lreg.predict(x_test)

# %%
lreg.score(x_test,true_p)
# Out:
# 0.9959183673469387

# %%
collections.Counter(pred)
# Out:
# Counter({0: 85, 1: 160})

# %%
true_p.value_counts()
# Out:
# 1    159
# 0     86
# Name: finalResult, dtype: int64

# %%
#Let's do same for portugal dataset

# %%
import seaborn as sns
#Using Pearson Correlation
plt.figure(figsize=(30,30))
cor = data_port.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
#taking a look at correlations once more
corr = data_port.corr()
corr = corr[['finalResult']]
corr
# Out:
#              finalResult
# school          0.297217
# sex            -0.078222
# age            -0.110722
# address         0.126663
# famsize        -0.052215
# Pstatus        -0.004241
# Medu            0.144803
# Fedu            0.146249
# Mjob            0.030411
# Fjob            0.051319
# reason          0.037822
# guardian       -0.084384
# traveltime     -0.057869
# studytime       0.165111
# failures       -0.380237
# schoolsup       0.034527
# famsup          0.037903
# paid           -0.053708
# activities      0.047276
# nursery        -0.007751
# higher          0.309708
# internet        0.088215
# romantic       -0.081177
# famrel          0.044987
# freetime       -0.093349
# goout          -0.067241
# Dalc           -0.123627
# Walc           -0.116249
# health         -0.009979
# absences       -0.087483
# G1              0.563070
# G2              0.592251
# G3              0.663157
# finalResult     1.000000

# %%
#G1,G2,G3 are higly correlated with finalResult

# %%
#We'll check outliers in corre;ated features

data_port['G1'].plot.box()
# Out:
# <AxesSubplot:>

# %%
data_port['G2'].plot.box()
# Out:
# <AxesSubplot:>

# %%
data_port['G3'].plot.box()
# Out:
# <AxesSubplot:>

# %%
#we can say there are some outliers in G1 G2 and G3, but that simply means few people have scored sxceptionally good in Portuese or exceptionally bad . 
#that is why their marks are shown as outlier. I don't think it would affect our analysis much

# %%
#tsne
from sklearn.manifold import TSNE

X = data_port.drop('finalResult', axis=1)
y = data_port['finalResult']

# %%
#t-SNE
X_reduced_tsne = TSNE(n_components=2, random_state=42).fit_transform(X.values)

# %%
# t-SNE scatter plot
import matplotlib.patches as mpatches

f, ax = plt.subplots(figsize=(24,16))


blue_patch = mpatches.Patch(color='#0A0AFF', label='fail')
red_patch = mpatches.Patch(color='#AF0000', label='pass')

ax.scatter(X_reduced_tsne[:,0], X_reduced_tsne[:,1], c=(y == 0), cmap='coolwarm', label='fail', linewidths=2)
ax.scatter(X_reduced_tsne[:,0], X_reduced_tsne[:,1], c=(y == 1), cmap='coolwarm', label='pass', linewidths=2)
ax.set_title('t-SNE', fontsize=14)

ax.grid(True)

ax.legend(handles=[blue_patch, red_patch])

# %%
#this is also well seperated , not perfect but good.

# %%
#NOW WE WILL DIVIDE DATASET INTO TEST AND TRAINING SET

# %%
trainpor=data_port[0:349]
testpor=data_port[350:]

x_trainpor=trainpor.drop('finalResult',1)
y_trainpor=trainpor['finalResult']

x_testpor=testpor.drop('finalResult',1)
true_ppor=testpor['finalResult']

# %%
#Logistic Regression Model
from sklearn.linear_model import LogisticRegression
lreg=LogisticRegression()

# %%
lreg.fit(x_trainpor,y_trainpor)
# Out:
# C:\Users\namee\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predpor=lreg.predict(x_testpor)

# %%
lreg.score(x_testpor,true_ppor)
# Out:
# 0.939799331103679

# %%
collections.Counter(predpor)
# Out:
# Counter({1: 248, 0: 51})

# %%
true_ppor.value_counts()
# Out:
# 1    230
# 0     69
# Name: finalResult, dtype: int64

# %%
#Accuracy is 99.6% for Student Maths Data using Logistic Regression
#and 94% for students Portuguese data using Logistic Regression

# %%
#confusion matrix portugues
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(true_ppor, predpor)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
#confusion matrix maths
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(true_p, pred)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
#KNN for portugues

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()

# %%
knn.fit(x_trainpor,y_trainpor)
# Out:
# KNeighborsClassifier()

# %%
predporknn=knn.predict(x_testpor)

# %%
knn.score(x_testpor,true_ppor)
# Out:
# 0.919732441471572

# %%
collections.Counter(predporknn)
# Out:
# Counter({1: 252, 0: 47})

# %%
true_ppor.value_counts()
# Out:
# 1    230
# 0     69
# Name: finalResult, dtype: int64

# %%
#confusion matrix portugues
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(true_ppor, predporknn)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
#KNN maths

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
predknn=knn.predict(x_test)

# %%
knn.score(x_test,true_p)
# Out:
# 0.9387755102040817

# %%
collections.Counter(predknn)
# Out:
# Counter({0: 73, 1: 172})

# %%
true_p.value_counts()
# Out:
# 1    159
# 0     86
# Name: finalResult, dtype: int64

# %%
#confusion matrix portugues
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(true_p, predknn)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
#Linear Discriminant Analysis Portuguese
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda=LinearDiscriminantAnalysis()

# %%
lda.fit(x_trainpor,y_trainpor)
# Out:
# LinearDiscriminantAnalysis()

# %%
predporlda=lda.predict(x_testpor)

# %%
lda.score(x_testpor,true_ppor)
# Out:
# 0.842809364548495

# %%
collections.Counter(predporlda)
# Out:
# Counter({1: 255, 0: 44})

# %%
true_ppor.value_counts()
# Out:
# 1    230
# 0     69
# Name: finalResult, dtype: int64

# %%
#confusion matrix portugues
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(true_ppor, predporlda)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
#Linear Discriminant Analysis Maths

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda=LinearDiscriminantAnalysis()

# %%
lda.fit(x_train,y_train)
# Out:
# LinearDiscriminantAnalysis()

# %%
predlda=lda.predict(x_test)

# %%
lda.score(x_test,true_p)
# Out:
# 0.8734693877551021

# %%
collections.Counter(predlda)
# Out:
# Counter({0: 87, 1: 158})

# %%
true_p.value_counts()
# Out:
# 1    159
# 0     86
# Name: finalResult, dtype: int64

# %%
#confusion matrix portugues
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(true_p, predlda)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
#SVM Maths

# %%
import numpy as np
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
clf = make_pipeline(StandardScaler(), SVC(gamma='auto'))
clf.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc', SVC(gamma='auto'))])

# %%
predsvc=clf.predict(x_test)

# %%
clf.score(x_test,true_p)
# Out:
# 0.8489795918367347

# %%
collections.Counter(predsvc)
# Out:
# Counter({0: 59, 1: 186})

# %%
true_p.value_counts()
# Out:
# 1    159
# 0     86
# Name: finalResult, dtype: int64

# %%
#confusion matrix portugues
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(true_p, predsvc)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
#SVM Portugues

# %%
import numpy as np
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
clf = make_pipeline(StandardScaler(), SVC(gamma='auto'))
clf.fit(x_trainpor, y_trainpor)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc', SVC(gamma='auto'))])

# %%
predporsvc=clf.predict(x_testpor)

# %%
clf.score(x_testpor,true_ppor)
# Out:
# 0.8260869565217391

# %%
collections.Counter(predporsvc)
# Out:
# Counter({1: 282, 0: 17})

# %%
true_ppor.value_counts()
# Out:
# 1    230
# 0     69
# Name: finalResult, dtype: int64

# %%
#confusion matrix portugues
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(true_ppor, predporsvc)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
#Decision Tree Classifier for portugues

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(x_trainpor, y_trainpor)

# %%
predpordt=clf.predict(x_testpor)

# %%
clf.score(x_testpor,true_ppor)
# Out:
# 1.0

# %%
collections.Counter(predpordt)
# Out:
# Counter({1: 230, 0: 69})

# %%
true_ppor.value_counts()
# Out:
# 1    230
# 0     69
# Name: finalResult, dtype: int64

# %%
#confusion matrix portugues
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(true_ppor, predpordt)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
tree.plot_tree(clf)
# Out:
# [Text(167.4, 163.07999999999998, 'X[32] <= 9.5\ngini = 0.162\nsamples = 349\nvalue = [31, 318]'),
#  Text(83.7, 54.360000000000014, 'gini = 0.0\nsamples = 31\nvalue = [31, 0]'),
#  Text(251.10000000000002, 54.360000000000014, 'gini = 0.0\nsamples = 318\nvalue = [0, 318]')]

# %%
#Decision Tree Classifier for Maths

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(x_train, y_train)

# %%
preddt=clf.predict(x_test)

# %%
clf.score(x_test,true_p)
# Out:
# 1.0

# %%
collections.Counter(preddt)
# Out:
# Counter({0: 86, 1: 159})

# %%
true_p.value_counts()
# Out:
# 1    159
# 0     86
# Name: finalResult, dtype: int64

# %%
#confusion matrix maths
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(true_p, preddt)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
tree.plot_tree(clf)
# Out:
# [Text(167.4, 163.07999999999998, 'X[32] <= 9.5\ngini = 0.416\nsamples = 149\nvalue = [44, 105]'),
#  Text(83.7, 54.360000000000014, 'gini = 0.0\nsamples = 44\nvalue = [44, 0]'),
#  Text(251.10000000000002, 54.360000000000014, 'gini = 0.0\nsamples = 105\nvalue = [0, 105]')]

# %%
#Random Forest Classifier portugues

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()

# %%
rfc = rfc.fit(x_trainpor, y_trainpor)

# %%
predporrfc=rfc.predict(x_testpor)

# %%
rfc.score(x_testpor,true_ppor)
# Out:
# 1.0

# %%
collections.Counter(predporrfc)
# Out:
# Counter({1: 230, 0: 69})

# %%
true_ppor.value_counts()
# Out:
# 1    230
# 0     69
# Name: finalResult, dtype: int64

# %%
#confusion matrix portugues
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(true_ppor, predporrfc)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
#RFC for maths

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()

# %%
rfc = rfc.fit(x_train, y_train)

# %%
predrfc=rfc.predict(x_test)

# %%
rfc.score(x_test,true_p)
# Out:
# 1.0

# %%
collections.Counter(predrfc)
# Out:
# Counter({0: 86, 1: 159})

# %%
true_p.value_counts()
# Out:
# 1    159
# 0     86
# Name: finalResult, dtype: int64

# %%
#confusion matrix portugues
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(true_p, predrfc)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
#ADAboost maths

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
clf = AdaBoostClassifier(n_estimators=100, random_state=0)

# %%
clf=clf.fit(x_train,y_train)

# %%
predada=clf.predict(x_test)

# %%
clf.score(x_test,true_p)
# Out:
# 1.0

# %%
collections.Counter(predada)
# Out:
# Counter({0: 86, 1: 159})

# %%
true_p.value_counts()
# Out:
# 1    159
# 0     86
# Name: finalResult, dtype: int64

# %%
#confusion matrix portugues
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(true_p, predada)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
#ADA Portugues

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
clf = AdaBoostClassifier(n_estimators=100, random_state=0)

# %%
clf=clf.fit(x_trainpor,y_trainpor)

# %%
predporada=clf.predict(x_testpor)

# %%
clf.score(x_testpor,true_ppor)
# Out:
# 1.0

# %%
collections.Counter(predporada)
# Out:
# Counter({1: 230, 0: 69})

# %%
true_ppor.value_counts()
# Out:
# 1    230
# 0     69
# Name: finalResult, dtype: int64

# %%
#confusion matrix portugues
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(true_ppor, predporada)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
#Analysis on Academic Grade Now

# %%
ag = {'A': 1,'B': 2,'C':3,'D':4,'E':5} 
data_por['academicGrade'] = [ag[item] for item in data_por['academic Grade']]

# %%
ag = {'A': 1,'B': 2,'C':3,'D':4,'E':5} 
data_mat['academicGrade'] = [ag[item] for item in data_mat['academic Grade']]

# %%
data_m=data_mat.drop('finalResult',1)
data_p=data_por.drop('finalResult',1)

# %%
data_m.head()
# Out:
#    school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0       1    0   18        1        1        0     4     4     2     3  ...
# 1       1    0   17        1        1        1     1     1     2     1  ...
# 2       1    0   15        1        0        1     1     1     2     1  ...
# 3       1    0   15        1        1        1     4     2     4     0  ...
# 4       1    0   16        1        1        1     3     3     1     1  ...
#
#    goout  Dalc  Walc  health  absences  G1  G2  G3  academic Grade  \
# 0      4     1     1       3         6   5   6   6               E
# 1      3     1     1       3         4   5   5   6               E
# 2      2     2     3       3        10   7   8  10               D
# 3      2     1     1       5         2  15  14  15               B
# 4      2     1     2       5         4   6  10  10               D
#
#    academicGrade
# 0              5
# 1              5
# 2              4
# 3              2
# ...

# %%
#Using Pearson Correlation

plt.figure(figsize=(30,30))
cor = data_m.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
#taking a look at correlations once more
corr = data_m.corr()
corr = corr[['academicGrade']]
corr
# Out:
#                academicGrade
# school             -0.070469
# sex                -0.111285
# age                 0.179495
# address            -0.105295
# famsize             0.051251
# Pstatus             0.025546
# Medu               -0.225312
# Fedu               -0.156111
# Mjob               -0.046715
# Fjob               -0.105127
# reason             -0.094501
# guardian            0.093751
# traveltime          0.118875
# studytime          -0.105144
# failures            0.317440
# schoolsup           0.180469
# famsup              0.047739
# paid               -0.008239
# activities         -0.031856
# nursery            -0.033837
# higher             -0.151764
# internet           -0.099419
# romantic            0.089538
# famrel             -0.053670
# freetime           -0.016017
# goout               0.148244
# Dalc                0.117715
# Walc                0.125737
# health              0.081680
# absences            0.131623
# G1                 -0.860782
# ...

# %%
#G1,G2,G3 are highly correlated

# %%
#we've alreadyplot outliers for g1,g2,g3 no need to do it again.

# %%
#TSNE

# %%
data_m=data_m.drop('academic Grade',1)
data_p=data_p.drop('academic Grade',1)

# %%
#tsne
from sklearn.manifold import TSNE

X = data_m.drop('academicGrade', axis=1)
y = data_m['academicGrade']

# %%
#t-SNE
X_reduced_tsne = TSNE(n_components=2, random_state=42).fit_transform(X.values)

# %%
# t-SNE scatter plot
import matplotlib.patches as mpatches

f, ax = plt.subplots(figsize=(24,16))


blue_patch = mpatches.Patch(color='#0A0AFF', label='A')
red_patch = mpatches.Patch(color='#AF0000', label='B')
black=mpatches.Patch(color='#000000',label='C')
green=mpatches.Patch(color='#9ACD32',label='D')
pink=mpatches.Patch(color='#FF69B4',label='E')


ax.scatter(X_reduced_tsne[:,0], X_reduced_tsne[:,1], c=(y == 1), cmap='coolwarm', label='A', linewidths=2)
ax.scatter(X_reduced_tsne[:,0], X_reduced_tsne[:,1], c=(y == 2), cmap='coolwarm', label='B', linewidths=2)
ax.scatter(X_reduced_tsne[:,0], X_reduced_tsne[:,1], c=(y == 3), cmap='coolwarm', label='C', linewidths=2)
ax.scatter(X_reduced_tsne[:,0], X_reduced_tsne[:,1], c=(y == 4), cmap='coolwarm', label='D', linewidths=2)
ax.scatter(X_reduced_tsne[:,0], X_reduced_tsne[:,1], c=(y == 5), cmap='coolwarm', label='E', linewidths=2)
ax.set_title('t-SNE', fontsize=14)

ax.grid(True)

ax.legend(handles=[blue_patch, red_patch,black,green,pink])

# %%
#NOW WE WILL DIVIDE DATASET INTO TEST AND TRAINING SET

# %%
trainpor=data_p[0:349]
testpor=data_p[350:]

x_trainpor=trainpor.drop('academicGrade',1)
y_trainpor=trainpor['academicGrade']

x_testpor=testpor.drop('academicGrade',1)
true_ppor=testpor['academicGrade']

# %%
train=data_m[0:230]
test=data_m[231:]

x_train=train.drop('academicGrade',1)
y_train=train['academicGrade']

x_test=test.drop('academicGrade',1)
true_p=test['academicGrade']

# %%
#Logistic Regression Model Maths
from sklearn.linear_model import LogisticRegression
lreg=LogisticRegression()

# %%
lreg.fit(x_train,y_train)
# Out:
# C:\Users\namee\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
pred=lreg.predict(x_test)

# %%
lreg.score(x_test,true_p)
# Out:
# 0.7073170731707317

# %%
collections.Counter(pred)
# Out:
# Counter({4: 45, 5: 63, 3: 36, 1: 6, 2: 14})

# %%
true_p.value_counts()
# Out:
# 5    54
# 4    45
# 3    29
# 2    22
# 1    14
# Name: academicGrade, dtype: int64

# %%
#confusion matrix maths
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(true_p, pred)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
#Logistic Regression Portuguese

# %%
from sklearn.linear_model import LogisticRegression
lreg=LogisticRegression()

# %%
lreg.fit(x_trainpor,y_trainpor)
# Out:
# C:\Users\namee\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predpor=lreg.predict(x_testpor)

# %%
lreg.score(x_testpor,true_ppor)
# Out:
# 0.6789297658862876

# %%
collections.Counter(predpor)
# Out:
# Counter({4: 114, 3: 63, 5: 50, 2: 36, 1: 36})

# %%
true_ppor.value_counts()
# Out:
# 4    95
# 5    69
# 2    49
# 3    46
# 1    40
# Name: academicGrade, dtype: int64

# %%
#confusion matrix maths
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(true_ppor, predpor)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
#LDA Maths

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda=LinearDiscriminantAnalysis()

# %%
lda.fit(x_train,y_train)
# Out:
# LinearDiscriminantAnalysis()

# %%
pred=lda.predict(x_test)

# %%
lda.score(x_test,true_p)
# Out:
# 0.6707317073170732

# %%
collections.Counter(pred)
# Out:
# Counter({4: 32, 5: 52, 2: 28, 3: 40, 1: 12})

# %%
true_p.value_counts()
# Out:
# 5    54
# 4    45
# 3    29
# 2    22
# 1    14
# Name: academicGrade, dtype: int64

# %%
#confusion matrix maths
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(true_p, pred)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
#LDA Portuguese

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda=LinearDiscriminantAnalysis()

# %%
lda.fit(x_trainpor,y_trainpor)
# Out:
# LinearDiscriminantAnalysis()

# %%
predpor=lda.predict(x_testpor)

# %%
lda.score(x_testpor,true_ppor)
# Out:
# 0.8595317725752508

# %%
collections.Counter(predpor)
# Out:
# Counter({4: 115, 1: 38, 2: 39, 3: 55, 5: 52})

# %%
true_ppor.value_counts()
# Out:
# 4    95
# 5    69
# 2    49
# 3    46
# 1    40
# Name: academicGrade, dtype: int64

# %%
#confusion matrix maths
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(true_ppor, predpor)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
#ADA boost Port

# %%
from sklearn.ensemble import AdaBoostClassifier
clf = AdaBoostClassifier(n_estimators=100, random_state=0)
clf=clf.fit(x_trainpor,y_trainpor)
predporada=clf.predict(x_testpor)

# %%
clf.score(x_testpor,true_ppor)
# Out:
# 0.8361204013377926

# %%
collections.Counter(predporada)
# Out:
# Counter({4: 95, 3: 95, 1: 40, 5: 69})

# %%
true_ppor.value_counts()
# Out:
# 4    95
# 5    69
# 2    49
# 3    46
# 1    40
# Name: academicGrade, dtype: int64

# %%
#confusion matrix portugues
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(true_ppor, predporada)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
#ADA boosts Maths

# %%
from sklearn.ensemble import AdaBoostClassifier
clf = AdaBoostClassifier(n_estimators=100, random_state=0)
clf=clf.fit(x_train,y_train)
predada=clf.predict(x_test)

# %%
clf.score(x_test,true_p)
# Out:
# 0.6890243902439024

# %%
collections.Counter(predada)
# Out:
# Counter({4: 96, 5: 54, 1: 14})

# %%
true_p.value_counts()
# Out:
# 5    54
# 4    45
# 3    29
# 2    22
# 1    14
# Name: academicGrade, dtype: int64

# %%
#confusion matrix portugues
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(true_p, predada)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
#Decision tree maths

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(x_train, y_train)
preddt=clf.predict(x_test)
clf.score(x_test,true_p)
# Out:
# 1.0

# %%
collections.Counter(preddt)
# Out:
# Counter({4: 45, 5: 54, 3: 29, 1: 14, 2: 22})

# %%
true_p.value_counts()
# Out:
# 5    54
# 4    45
# 3    29
# 2    22
# 1    14
# Name: academicGrade, dtype: int64

# %%
#confusion matrix maths
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(true_p, preddt)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');
tree.plot_tree(clf)
# Out:
# [Text(62.12571428571429, 195.696, 'X[32] <= 9.5\ngini = 0.768\nsamples = 230\nvalue = [26, 37, 33, 58, 76]'),
#  Text(31.062857142857144, 152.208, 'gini = 0.0\nsamples = 76\nvalue = [0, 0, 0, 0, 76]'),
#  Text(93.18857142857144, 152.208, 'X[32] <= 11.5\ngini = 0.726\nsamples = 154\nvalue = [26, 37, 33, 58, 0]'),
#  Text(62.12571428571429, 108.72, 'gini = 0.0\nsamples = 58\nvalue = [0, 0, 0, 58, 0]'),
#  Text(124.25142857142858, 108.72, 'X[32] <= 13.5\ngini = 0.66\nsamples = 96\nvalue = [26, 37, 33, 0, 0]'),
#  Text(93.18857142857144, 65.232, 'gini = 0.0\nsamples = 33\nvalue = [0, 0, 33, 0, 0]'),
#  Text(155.31428571428572, 65.232, 'X[32] <= 15.5\ngini = 0.485\nsamples = 63\nvalue = [26, 37, 0, 0, 0]'),
#  Text(124.25142857142858, 21.744, 'gini = 0.0\nsamples = 37\nvalue = [0, 37, 0, 0, 0]'),
#  Text(186.37714285714287, 21.744, 'gini = 0.0\nsamples = 26\nvalue = [26, 0, 0, 0, 0]')]

# %%
#Decision Tree Portuguese

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(x_trainpor, y_trainpor)
preddt=clf.predict(x_testpor)
clf.score(x_testpor,true_ppor)
# Out:
# 1.0

# %%
collections.Counter(preddt)
# Out:
# Counter({4: 95, 2: 49, 1: 40, 3: 46, 5: 69})

# %%
true_ppor.value_counts()
# Out:
# 4    95
# 5    69
# 2    49
# 3    46
# 1    40
# Name: academicGrade, dtype: int64

# %%
tree.plot_tree(clf)
# Out:
# [Text(96.64, 190.26, 'X[32] <= 11.5\ngini = 0.758\nsamples = 349\nvalue = [41, 63, 108, 106, 31]'),
#  Text(48.32, 135.9, 'X[32] <= 9.5\ngini = 0.35\nsamples = 137\nvalue = [0, 0, 0, 106, 31]'),
#  Text(24.16, 81.53999999999999, 'gini = 0.0\nsamples = 31\nvalue = [0, 0, 0, 0, 31]'),
#  Text(72.48, 81.53999999999999, 'gini = 0.0\nsamples = 106\nvalue = [0, 0, 0, 106, 0]'),
#  Text(144.96, 135.9, 'X[32] <= 13.5\ngini = 0.615\nsamples = 212\nvalue = [41, 63, 108, 0, 0]'),
#  Text(120.8, 81.53999999999999, 'gini = 0.0\nsamples = 108\nvalue = [0, 0, 108, 0, 0]'),
#  Text(169.12, 81.53999999999999, 'X[32] <= 15.5\ngini = 0.478\nsamples = 104\nvalue = [41, 63, 0, 0, 0]'),
#  Text(144.96, 27.180000000000007, 'gini = 0.0\nsamples = 63\nvalue = [0, 63, 0, 0, 0]'),
#  Text(193.28, 27.180000000000007, 'gini = 0.0\nsamples = 41\nvalue = [41, 0, 0, 0, 0]')]

# %%
#confusion matrix maths
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(true_ppor, preddt)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
#Random Classifier Port

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc = rfc.fit(x_trainpor, y_trainpor)
predporrfc=rfc.predict(x_testpor)
rfc.score(x_testpor,true_ppor)
# Out:
# 0.9632107023411371

# %%
collections.Counter(predporrfc)
# Out:
# Counter({4: 100, 2: 54, 1: 35, 3: 47, 5: 63})

# %%
true_ppor.value_counts()
# Out:
# 4    95
# 5    69
# 2    49
# 3    46
# 1    40
# Name: academicGrade, dtype: int64

# %%
#confusion matrix portugues
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(true_ppor, predporrfc)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
#RFC Maths

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc = rfc.fit(x_train, y_train)
predrfc=rfc.predict(x_test)
rfc.score(x_test,true_p)
# Out:
# 0.9878048780487805

# %%
collections.Counter(predrfc)
# Out:
# Counter({4: 45, 5: 54, 3: 29, 1: 12, 2: 24})

# %%
true_p.value_counts()
# Out:
# 5    54
# 4    45
# 3    29
# 2    22
# 1    14
# Name: academicGrade, dtype: int64

# %%
#confusion matrix portugues
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(true_p, predrfc)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
#Voting classifier maths

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
# group / ensemble of models
estimator = []
estimator.append(('LR', 
                  LogisticRegression(solver ='lbfgs', 
                                     multi_class ='multinomial', 
                                     max_iter = 200)))
estimator.append(('SVC', SVC(gamma ='auto', probability = True)))
estimator.append(('DTC', DecisionTreeClassifier()))
  
# Voting Classifier with hard voting
vot_hard = VotingClassifier(estimators = estimator, voting ='hard')
vot_hard.fit(x_train, y_train)
y_pred = vot_hard.predict(x_test)
  
# using accuracy_score metric to predict accuracy
score = accuracy_score(true_p, y_pred)
print("Hard Voting Score % d" % score)
# Out:
# Hard Voting Score  0
# C:\Users\namee\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Voting Classifier with soft voting
vot_soft = VotingClassifier(estimators = estimator, voting ='soft')
vot_soft.fit(x_train, y_train)
y_pred = vot_soft.predict(x_test)
  
# using accuracy_score
score = accuracy_score(true_p, y_pred)
print("Soft Voting Score % d" % score)
# Out:
# Soft Voting Score  0
# C:\Users\namee\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
